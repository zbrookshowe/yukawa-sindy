# %%
import matplotlib.pyplot as plt
import numpy as np

import Yukawa_SINDy as ys
import cross_validation as cv
from importlib import reload

# %%
reload(cv)
# Out:
# <module 'cross_validation' from '/Users/zbh0005/Library/CloudStorage/OneDrive-AuburnUniversity/Documents/Code/yukawa-sindy/cross_validation.py'>

# %%
noise_space = [1e-4]
threshold_space = [1.]
all_coefs, all_rmses = cv.two_body_param_scan(noise_space, threshold_space)
# Out:
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:191: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:191: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(
# /opt/anaconda3/envs/yukawa-sindy-vetted/lib/python3.12/site-packages/pysindy/optimizers/stlsq.py:201: UserWarning: Sparsity parameter is too big (1.0) and eliminated all coefficients
#   warnings.warn(

# %%
x = all_rmses[0]

# %%
x
# Out:
# <xarray.DataArray (threshold: 1, formulation: 2, cv_selection: 2)> Size: 32B
# array([[[ 1.98855462,  1.98854298],
#         [ 2.89830266, 12.74639469]]])
# Coordinates:
#   * threshold     (threshold) float64 8B 1.0
#   * formulation   (formulation) <U6 48B 'weak' 'strong'
#   * cv_selection  (cv_selection) <U7 56B 'best' 'average'
# Attributes:
#     noise_level:  0.0001

# %%
x.sel(threshold=1., formulation='weak', cv_selection='best')
# Out:
# <xarray.DataArray ()> Size: 8B
# array(1.98855462)
# Coordinates:
#     threshold     float64 8B 1.0
#     formulation   <U6 24B 'weak'
#     cv_selection  <U7 28B 'best'
# Attributes:
#     noise_level:  0.0001
